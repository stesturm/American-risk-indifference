# %%
#https://www.tensorflow.org/tutorials/quickstart/advanced 

import tensorflow as tf

print("TensorFlow version:", tf.__version__)

from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras import Model

import tensorflow.keras as keras

import numpy as np

import matplotlib.pyplot as plt

#import tensorflow.keras.backend as K
# Out:
# 2024-08-08 12:10:36.983662: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TensorFlow version: 2.10.0

# %%
# Universal parameters
batchSize = 1100 # batchSize = number of paths to be generated

d = 2 # dimension of forward process


seed = 0 #168
tf.random.set_seed(
    seed
)
tf.keras.utils.set_random_seed(
    seed
)

print('Number of paths (sample data) = ', batchSize)




X_0 = 100 # initial price
print('initial price = ', X_0) 
V_0 = .15  # initial volatility
print('initial Vol = ', V_0)



mu = .08
print('mu = ', mu )
alpha = 5 
print('alpha = ', alpha)
m = 0 
print('m = ', m)
nu = 1
print('nu = ', nu)
a = nu * np.sqrt(2 * alpha)
print('nu * sqrt(2 alpha ) = ', a)
rho = -.2
print('rho = ', rho)
gamma = 1
print('gamma = ', gamma )
eta = .2 
print('eta = ', eta)
timeSteps = 10  #20 #50 
print('Total number of time steps = ', timeSteps )
r = 0.02 # .05
print('risk free rate r = ', r)
T = 1/4 # terminal time
print('T = ', T)
dt = T / timeSteps
print('dt = ', dt)

strikes = [70,75,80,85,90,95,100,105,110,115]

print('-------------Beginning computation-----------------')
# Out:
# Number of paths (sample data) =  1100
# initial price =  100
# initial Vol =  0.15
# mu =  0.08
# alpha =  5
# m =  0
# nu =  1
# nu * sqrt(2 alpha ) =  3.1622776601683795
# rho =  -0.2
# gamma =  1
# eta =  0.2
# Total number of time steps =  10
# risk free rate r =  0.02
# T =  0.25
# dt =  0.025
# -------------Beginning computation-----------------

# %%
def trainingData(seed): # = 168):
    tf.random.set_seed(seed)
    std_normal = tf.random.normal([batchSize,  # [x,   [number of paths,
                                   timeSteps + 1,  #  y, =  number of values in each path,            = tensor shape
                                   2],         #  z]    dim of each path 
                                  mean = 0.0,
                                  stddev = 1.0,
                                  dtype = tf.dtypes.float32,
                                  seed = seed,
                                  name = None)
    dW = std_normal * np.sqrt(dt)
    X = tf.Variable(tf.ones([batchSize, timeSteps + 1, 2], 
                            dtype = tf.dtypes.float32) * tf.constant([X_0, V_0]))
    for i in range(timeSteps):
        stockTerm1 = mu * X[:,i, 0] * dt
        stockTerm2 = (.7 / (np.pi) * (tf.math.atan(X[:,i, 1] - 1) + np.pi/2) + .03) * X[:, i,0] * dW[:,i,0] # sigma(Y_t)
        stockTerm3 = -r * X[:,i,0] * dt
        X[:, i+1, 0].assign(X[:,i, 0] + stockTerm1 + stockTerm2 + stockTerm3)
        volTerm1 = alpha * (m - X[:,i,1]) * dt
        volTerm2 = a * (rho *dW[:,i,0] + np.sqrt(1 - rho ** 2)* dW[:,i,1])
        X[:, i+1, 1].assign(X[:, i, 1] + volTerm1 + volTerm2) 
        
       # X = X[:, i+1, :].assign(X[:, i, :] + r*X[:, i, :]*dt + sigma*X[:, i, :]*dW[:, i, :])
    return X, dW

    

#terminal condition
def fun_g(X, K, t):
    # print(X.shape)
    g = tf.math.maximum(K * tf.math.exp((-r * (t/timeSteps) * T)) - X, 0)
    return g


def fun_bdy(z,y):
    F = -1 * z + y
    return F

# %%
X, dW = trainingData(seed)
print('sample path = ', X[0,:,:])
# print('sample brownian motion = ', dW[0,:,:])
print('sample BM mean: ', tf.math.reduce_mean(dW), '| variance: ', tf.math.reduce_variance(dW))
# Out:
# sample path =  tf.Tensor(
# [[100.           0.15      ]
#  [100.586975     1.4899718 ]
#  [ 86.982605     1.6355829 ]
#  [ 77.92782      1.5378664 ]
#  [ 81.3299       0.53700984]
#  [ 81.103424     0.1833899 ]
#  [ 84.22564      0.22403565]
#  [ 87.86331      0.3189113 ]
#  [ 91.61486     -0.48350307]
#  [ 92.21429     -0.5280182 ]
#  [ 92.610016    -1.2509947 ]], shape=(11, 2), dtype=float32)
# sample BM mean:  tf.Tensor(0.001961416, shape=(), dtype=float32) | variance:  tf.Tensor(0.024696153, shape=(), dtype=float32)
# 2024-08-08 12:10:41.843220: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
X, dW = trainingData(seed)

# %%
print('Computing the Boundary')
#X, dW = trainingData(seed)
for K in strikes:
    print('Strike = ', K)
    L = fun_g(X[:, timeSteps, 0], K, timeSteps)
 
    print(tf.math.reduce_mean(X[:, timeSteps, 0]))
    print(tf.math.reduce_mean(L))
    
    np.savetxt("Buy-Boundarypredictions_"+str(timeSteps)+"K_"+str(K)+".csv", L, delimiter = ",")
    
    for time in range(timeSteps -1, -1, -1):
        #print('timeStep =', time)
        z = np.loadtxt("BSDE0predictions_"+str(time)+"_y.csv", delimiter = ",", dtype = 'float32')
        #print(z.shape)
        #z = z.reshape((1000, 1))
        y = fun_g(X[:, time, 0], K, time)
        #print(y.shape)

        L = fun_bdy(z,y) 
        print('timestep = ', time, 'Boundary = ', tf.math.reduce_mean(L))
        np.savetxt("Buy-Boundarypredictions_"+str(time)+"K_"+str(K)+".csv", L, delimiter = ",")    

print('Boundary Computed')
print('============Computing the RBSDE============')
# Out:
# Computing the Boundary
# Strike =  70
# tf.Tensor(102.154106, shape=(), dtype=float32)
# tf.Tensor(0.10117897, shape=(), dtype=float32)
# timestep =  9 Boundary =  tf.Tensor(0.091170445, shape=(), dtype=float32)
# timestep =  8 Boundary =  tf.Tensor(0.04022484, shape=(), dtype=float32)
# timestep =  7 Boundary =  tf.Tensor(0.029531656, shape=(), dtype=float32)
# timestep =  6 Boundary =  tf.Tensor(0.01620361, shape=(), dtype=float32)
# timestep =  5 Boundary =  tf.Tensor(0.008362312, shape=(), dtype=float32)
# timestep =  4 Boundary =  tf.Tensor(0.008656919, shape=(), dtype=float32)
# timestep =  3 Boundary =  tf.Tensor(0.009117508, shape=(), dtype=float32)
# timestep =  2 Boundary =  tf.Tensor(0.009653919, shape=(), dtype=float32)
# timestep =  1 Boundary =  tf.Tensor(0.010844309, shape=(), dtype=float32)
# timestep =  0 Boundary =  tf.Tensor(0.0117490105, shape=(), dtype=float32)
# Strike =  75
# tf.Tensor(102.154106, shape=(), dtype=float32)
# tf.Tensor(0.1777233, shape=(), dtype=float32)
# timestep =  9 Boundary =  tf.Tensor(0.1592048, shape=(), dtype=float32)
# timestep =  8 Boundary =  tf.Tensor(0.103295825, shape=(), dtype=float32)
# timestep =  7 Boundary =  tf.Tensor(0.07307699, shape=(), dtype=float32)
# timestep =  6 Boundary =  tf.Tensor(0.055802695, shape=(), dtype=float32)
# timestep =  5 Boundary =  tf.Tensor(0.020368269, shape=(), dtype=float32)
# timestep =  4 Boundary =  tf.Tensor(0.008656919, shape=(), dtype=float32)
# timestep =  3 Boundary =  tf.Tensor(0.009117508, shape=(), dtype=float32)
# timestep =  2 Boundary =  tf.Tensor(0.009653919, shape=(), dtype=float32)
# timestep =  1 Boundary =  tf.Tensor(0.010844309, shape=(), dtype=float32)
# timestep =  0 Boundary =  tf.Tensor(0.0117490105, shape=(), dtype=float32)
# Strike =  80
# tf.Tensor(102.154106, shape=(), dtype=float32)
# tf.Tensor(0.32412863, shape=(), dtype=float32)
# timestep =  9 Boundary =  tf.Tensor(0.28327104, shape=(), dtype=float32)
# timestep =  8 Boundary =  tf.Tensor(0.21990898, shape=(), dtype=float32)
# timestep =  7 Boundary =  tf.Tensor(0.15330295, shape=(), dtype=float32)
# timestep =  6 Boundary =  tf.Tensor(0.13311554, shape=(), dtype=float32)
# timestep =  5 Boundary =  tf.Tensor(0.046391234, shape=(), dtype=float32)
# timestep =  4 Boundary =  tf.Tensor(0.020329246, shape=(), dtype=float32)
# timestep =  3 Boundary =  tf.Tensor(0.015623382, shape=(), dtype=float32)
# timestep =  2 Boundary =  tf.Tensor(0.009653919, shape=(), dtype=float32)
# timestep =  1 Boundary =  tf.Tensor(0.010844309, shape=(), dtype=float32)
# timestep =  0 Boundary =  tf.Tensor(0.0117490105, shape=(), dtype=float32)
# Strike =  85
# tf.Tensor(102.154106, shape=(), dtype=float32)
# tf.Tensor(0.62483966, shape=(), dtype=float32)
# timestep =  9 Boundary =  tf.Tensor(0.5476924, shape=(), dtype=float32)
# timestep =  8 Boundary =  tf.Tensor(0.4466428, shape=(), dtype=float32)
# timestep =  7 Boundary =  tf.Tensor(0.33422506, shape=(), dtype=float32)
# timestep =  6 Boundary =  tf.Tensor(0.29499856, shape=(), dtype=float32)
# timestep =  5 Boundary =  tf.Tensor(0.14482707, shape=(), dtype=float32)
# timestep =  4 Boundary =  tf.Tensor(0.081665345, shape=(), dtype=float32)
# timestep =  3 Boundary =  tf.Tensor(0.052152906, shape=(), dtype=float32)
# timestep =  2 Boundary =  tf.Tensor(0.010558523, shape=(), dtype=float32)
# timestep =  1 Boundary =  tf.Tensor(0.010844309, shape=(), dtype=float32)
# timestep =  0 Boundary =  tf.Tensor(0.0117490105, shape=(), dtype=float32)
# Strike =  90
# tf.Tensor(102.154106, shape=(), dtype=float32)
# tf.Tensor(1.1946193, shape=(), dtype=float32)
# timestep =  9 Boundary =  tf.Tensor(1.0839274, shape=(), dtype=float32)
# timestep =  8 Boundary =  tf.Tensor(0.8984604, shape=(), dtype=float32)
# timestep =  7 Boundary =  tf.Tensor(0.7358663, shape=(), dtype=float32)
# timestep =  6 Boundary =  tf.Tensor(0.62948996, shape=(), dtype=float32)
# timestep =  5 Boundary =  tf.Tensor(0.42726573, shape=(), dtype=float32)
# timestep =  4 Boundary =  tf.Tensor(0.2850475, shape=(), dtype=float32)
# timestep =  3 Boundary =  tf.Tensor(0.18273856, shape=(), dtype=float32)
# timestep =  2 Boundary =  tf.Tensor(0.061271112, shape=(), dtype=float32)
# timestep =  1 Boundary =  tf.Tensor(0.016699353, shape=(), dtype=float32)
# timestep =  0 Boundary =  tf.Tensor(0.0117490105, shape=(), dtype=float32)
# Strike =  95
# tf.Tensor(102.154106, shape=(), dtype=float32)
# tf.Tensor(2.2065997, shape=(), dtype=float32)
# timestep =  9 Boundary =  tf.Tensor(2.0974946, shape=(), dtype=float32)
# timestep =  8 Boundary =  tf.Tensor(1.8467516, shape=(), dtype=float32)
# timestep =  7 Boundary =  tf.Tensor(1.5749547, shape=(), dtype=float32)
# timestep =  6 Boundary =  tf.Tensor(1.4369612, shape=(), dtype=float32)
# timestep =  5 Boundary =  tf.Tensor(1.1565428, shape=(), dtype=float32)
# timestep =  4 Boundary =  tf.Tensor(0.8919751, shape=(), dtype=float32)
# timestep =  3 Boundary =  tf.Tensor(0.67530787, shape=(), dtype=float32)
# timestep =  2 Boundary =  tf.Tensor(0.37952754, shape=(), dtype=float32)
# timestep =  1 Boundary =  tf.Tensor(0.111997895, shape=(), dtype=float32)
# timestep =  0 Boundary =  tf.Tensor(0.0117490105, shape=(), dtype=float32)
# Strike =  100
# tf.Tensor(102.154106, shape=(), dtype=float32)
# tf.Tensor(3.862705, shape=(), dtype=float32)
# timestep =  9 Boundary =  tf.Tensor(3.781544, shape=(), dtype=float32)
# timestep =  8 Boundary =  tf.Tensor(3.5151355, shape=(), dtype=float32)
# timestep =  7 Boundary =  tf.Tensor(3.189464, shape=(), dtype=float32)
# timestep =  6 Boundary =  tf.Tensor(3.0618174, shape=(), dtype=float32)
# timestep =  5 Boundary =  tf.Tensor(2.8031943, shape=(), dtype=float32)
# timestep =  4 Boundary =  tf.Tensor(2.4322612, shape=(), dtype=float32)
# timestep =  3 Boundary =  tf.Tensor(2.1414552, shape=(), dtype=float32)
# timestep =  2 Boundary =  tf.Tensor(1.8154562, shape=(), dtype=float32)
# timestep =  1 Boundary =  tf.Tensor(1.2505138, shape=(), dtype=float32)
# timestep =  0 Boundary =  tf.Tensor(0.0117490105, shape=(), dtype=float32)
# Strike =  105
# tf.Tensor(102.154106, shape=(), dtype=float32)
# tf.Tensor(6.395463, shape=(), dtype=float32)
# timestep =  9 Boundary =  tf.Tensor(6.3424087, shape=(), dtype=float32)
# timestep =  8 Boundary =  tf.Tensor(6.124059, shape=(), dtype=float32)
# timestep =  7 Boundary =  tf.Tensor(5.8208575, shape=(), dtype=float32)
# timestep =  6 Boundary =  tf.Tensor(5.7514744, shape=(), dtype=float32)
# timestep =  5 Boundary =  tf.Tensor(5.6168246, shape=(), dtype=float32)
# timestep =  4 Boundary =  tf.Tensor(5.364419, shape=(), dtype=float32)
# timestep =  3 Boundary =  tf.Tensor(5.1326137, shape=(), dtype=float32)
# timestep =  2 Boundary =  tf.Tensor(5.0480742, shape=(), dtype=float32)
# timestep =  1 Boundary =  tf.Tensor(4.87116, shape=(), dtype=float32)
# timestep =  0 Boundary =  tf.Tensor(5.0117483, shape=(), dtype=float32)
# Strike =  110
# tf.Tensor(102.154106, shape=(), dtype=float32)
# tf.Tensor(9.767559, shape=(), dtype=float32)
# timestep =  9 Boundary =  tf.Tensor(9.735177, shape=(), dtype=float32)
# timestep =  8 Boundary =  tf.Tensor(9.5859165, shape=(), dtype=float32)
# timestep =  7 Boundary =  tf.Tensor(9.409843, shape=(), dtype=float32)
# timestep =  6 Boundary =  tf.Tensor(9.414639, shape=(), dtype=float32)
# timestep =  5 Boundary =  tf.Tensor(9.470677, shape=(), dtype=float32)
# timestep =  4 Boundary =  tf.Tensor(9.410099, shape=(), dtype=float32)
# timestep =  3 Boundary =  tf.Tensor(9.401128, shape=(), dtype=float32)
# timestep =  2 Boundary =  tf.Tensor(9.580164, shape=(), dtype=float32)
# timestep =  1 Boundary =  tf.Tensor(9.730623, shape=(), dtype=float32)
# timestep =  0 Boundary =  tf.Tensor(10.011742, shape=(), dtype=float32)
# Strike =  115
# tf.Tensor(102.154106, shape=(), dtype=float32)
# tf.Tensor(13.723221, shape=(), dtype=float32)
# timestep =  9 Boundary =  tf.Tensor(13.741357, shape=(), dtype=float32)
# timestep =  8 Boundary =  tf.Tensor(13.689229, shape=(), dtype=float32)
# timestep =  7 Boundary =  tf.Tensor(13.662491, shape=(), dtype=float32)
# timestep =  6 Boundary =  tf.Tensor(13.734567, shape=(), dtype=float32)
# timestep =  5 Boundary =  tf.Tensor(13.948067, shape=(), dtype=float32)
# timestep =  4 Boundary =  tf.Tensor(14.030392, shape=(), dtype=float32)
# timestep =  3 Boundary =  tf.Tensor(14.192257, shape=(), dtype=float32)
# timestep =  2 Boundary =  tf.Tensor(14.513432, shape=(), dtype=float32)
# timestep =  1 Boundary =  tf.Tensor(14.727417, shape=(), dtype=float32)
# timestep =  0 Boundary =  tf.Tensor(15.011735, shape=(), dtype=float32)
# Boundary Computed
# ============Computing the RBSDE============
